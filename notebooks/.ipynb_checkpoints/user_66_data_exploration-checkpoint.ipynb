# %%
import sys
import os
import matplotlib.pyplot as plt

# %%
sys.path.append(os.path.abspath('../scripts'))

# %%
from parse_tcx import parse_tcx_to_df

# %%
df, session_total_sec, sessions_avg_hr, session_max_hr = parse_tcx_to_df('../data/66-d.tcx')

# %%
plt.figure(figsize=(14,5))
plt.plot(df['elapsed_min'], df['heart_rate'])
plt.xlabel('Elapsed Minutes')
plt.ylabel('Heart Rate (BPM) ')
plt.title('Heart Rate Over Time: User 66')
plt.show()

# %%
import matplotlib.image as mpimg

# %%
img = mpimg.imread('../charts_cropped/user_66.png')

# %%
session_duration_min = session_total_sec / 60
fig, ax = plt.subplots(figsize=(14,5))
ax.imshow(img, aspect='auto', extent=[0, session_duration_min, 85, 185], alpha=0.45, zorder=0)
ax.plot(df['elapsed_min'], df['heart_rate'], color='blue', linewidth=2, label='Parsed HR Data', zorder=1)
ax.set_xlabel('Elapsed Minutes')
ax.set_ylabel('Heart Rate (BPM)')
ax.set_title('Overlay: Garmin HR Graph (User 66) vs Parsed HR Data (User 66)')
ax.legend()
plt.show()

# %%
# Manually defined station cutoffs (elapsed minutes) for user 66
cutoffs = [
    (1.8, 12.7),   # Station 1: after briefing/warmup
    (14.8, 25.8),  # Station 2
    (27.7, 39.0),  # Station 3
]

# %%
station_rows = []

for i, (start_min, end_min) in enumerate(cutoffs, 1):
    segment = df[(df['elapsed_min'] >= start_min) & (df['elapsed_min'] < end_min)]
    if segment.empty:
        continue
    station_row = {
        'user_id': 66,
        'gender': 'NA',
        'circuit_type': 'NA',
        'station_number': i,
        'station_name': 'NA',
        'session_start_time': df['timestamp'].iloc[0],
        'session_end_time': df['timestamp'].iloc[-1],
        'session_duration_min': session_duration_min,
        'session_avg_hr': sessions_avg_hr,
        'session_max_hr': session_max_hr,
        'station_start_time': segment['timestamp'].iloc[0],
        'station_end_time': segment['timestamp'].iloc[-1],
        'station_duration_min': (segment['timestamp'].iloc[-1] - segment['timestamp'].iloc[0]).total_seconds() / 60,
        'station_avg_hr': segment['heart_rate'].mean(),
        'station_max_hr': segment['heart_rate'].max(),
        'motivation': 'NA',
        'fun': 'NA',
        'subjective_exertion': 'NA',
        'sports_exp': 'NA',
        'gaming_exp': 'NA',
        'data_quality': 'Good',
        'notes': ''
    }
    station_rows.append(station_row)

# %%
import pandas as pd
station_df = pd.DataFrame(station_rows)
display(station_df)
# Out:
#    user_id gender circuit_type  station_number station_name  \
# 0       66     NA           NA               1           NA
# 1       66     NA           NA               2           NA
# 2       66     NA           NA               3           NA
#
#          session_start_time          session_end_time  session_duration_min  \
# 0 2025-04-06 10:33:23+00:00 2025-04-06 11:18:11+00:00                  44.8
# 1 2025-04-06 10:33:23+00:00 2025-04-06 11:18:11+00:00                  44.8
# 2 2025-04-06 10:33:23+00:00 2025-04-06 11:18:11+00:00                  44.8
#
#    session_avg_hr  session_max_hr  ... station_duration_min station_avg_hr  \
# 0      144.760563             182  ...            10.666667     156.764706
# 1      144.760563             182  ...            10.033333     171.547619
# 2      144.760563             182  ...            11.116667     125.633333
#
#    station_max_hr  motivation  fun subjective_exertion sports_exp gaming_exp  \
# 0             180          NA   NA                  NA         NA         NA
# 1             182          NA   NA                  NA         NA         NA
# 2             152          NA   NA                  NA         NA         NA
#
#   data_quality notes
# 0         Good
# 1         Good
# 2         Good
#
# [3 rows x 22 columns]

# %%
station_df.to_csv('../output/processed/user_66_station_data.csv', index=False)
